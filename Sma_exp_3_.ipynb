# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('/content/Aggregated_Metrics_By_Video.csv')
df2 = pd.read_csv('/content/Video_Performance_Over_Time.csv')

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['Video', 'Video title', 'Video pub­lish time', 'Com­ments ad­ded',
#        'Shares', 'Dis­likes', 'Likes', 'Sub­scribers lost',
#        'Sub­scribers gained', 'RPM (USD)', 'CPM (USD)',
#        'Av­er­age per­cent­age viewed (%)', 'Av­er­age view dur­a­tion',
#        'Views', 'Watch time (hours)', 'Sub­scribers',
#        'Your es­tim­ated rev­en­ue (USD)', 'Im­pres­sions',
#        'Im­pres­sions click-through rate (%)'],
#       dtype='object')
# Index(['Date', 'Video Title', 'External Video ID', 'Video Length',
#        'Thumbnail link', 'Views', 'Video Likes Added', 'Video Dislikes Added',
#        'Video Likes Removed', 'User Subscriptions Added',
#        'User Subscriptions Removed', 'Average View Percentage',
#        'Average Watch Time', 'User Comments Added'],
#       dtype='object')

# %%
df1.head()
# Out:
#          Video                                        Video title  \
# 0        Total                                                NaN
# 1  4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2  78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3  hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4  uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
#
#   Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes   Likes  \
# 0                 NaN             14197   39640       3902  225021
# 1         May 8, 2020               907    9583        942   46903
# 2        Nov 12, 2020               412       4          4     130
# 3        Jul 16, 2020               402     152         15     881
# 4        Aug 29, 2020               375     367         22    2622
#
#    Sub­scribers lost  Sub­scribers gained  RPM (USD)  CPM (USD)  \
# 0              45790               229241      5.276     11.990
# ...

# %%
df2.head()
# Out:
#           Date                                        Video Title  \
# 0  19 Jan 2022  Kaggle Project From Scratch - Part 2 (Explorat...
# 1  19 Jan 2022     Welcome To My Channel | Ken Jee | Data Science
# 2  19 Jan 2022  How She Dominated the FAANG Data Science Inter...
# 3  19 Jan 2022    The 9 Books That Changed My Perspective in 2019
# 4  19 Jan 2022  Interview with the Director of AI Research @ N...
#
#   External Video ID  Video Length  \
# 0       KQ80oD_boBM          2191
# 1       smeFkHwnM_k            51
# 2       vfV4nm004VQ          2686
# 3       3TrAYmrmA8o           980
# 4       Xgg7dIKys9E          2904
#
#                                      Thumbnail link  Views  Video Likes Added  \
# 0  https://i.ytimg.com/vi/KQ80oD_boBM/hqdefault.jpg     13                  0
# 1  https://i.ytimg.com/vi/smeFkHwnM_k/hqdefault.jpg      2                  0
# 2  https://i.ytimg.com/vi/vfV4nm004VQ/hqdefault.jpg     10                  0
# ...

# %%
df1.drop(df1.index[0], inplace = True)
df1.reset_index(drop = True, inplace =True)
df1.head(2)
# Out:
#          Video                                        Video title  \
# 0  4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 1  78LjdAAw0wA                  100K Channel Update + AMA Stream!
#
#   Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes  Likes  \
# 0         May 8, 2020               907    9583        942  46903
# 1        Nov 12, 2020               412       4          4    130
#
#    Sub­scribers lost  Sub­scribers gained  RPM (USD)  CPM (USD)  \
# 0                451                46904      6.353     12.835
# 1                 15                   12      2.668      6.259
#
#    Av­er­age per­cent­age viewed (%) Av­er­age view dur­a­tion    Views  \
# 0                              36.65                   0:03:09  1253559
# 1                               6.26                   0:05:14     2291
#
#    Watch time (hours)  Sub­scribers  Your es­tim­ated rev­en­ue (USD)  \
# 0          65850.7042         46453                          7959.533
# ...

# %%
df2.drop(df1.index[0], inplace = True)
df2.reset_index(drop = True, inplace =True)
df2.head(2)
# Out:
#           Date                                        Video Title  \
# 0  19 Jan 2022     Welcome To My Channel | Ken Jee | Data Science
# 1  19 Jan 2022  How She Dominated the FAANG Data Science Inter...
#
#   External Video ID  Video Length  \
# 0       smeFkHwnM_k            51
# 1       vfV4nm004VQ          2686
#
#                                      Thumbnail link  Views  Video Likes Added  \
# 0  https://i.ytimg.com/vi/smeFkHwnM_k/hqdefault.jpg      2                  0
# 1  https://i.ytimg.com/vi/vfV4nm004VQ/hqdefault.jpg     10                  0
#
#    Video Dislikes Added  Video Likes Removed  User Subscriptions Added  \
# 0                     0                    0                         1
# 1                     0                    0                         0
#
#    User Subscriptions Removed  Average View Percentage  Average Watch Time  \
# 0                           0                 0.471255             24.0340
# ...

# %%
df1.dtypes
# Out:
# Video                                    object
# Video title                              object
# Video pub­lish time                      object
# Com­ments ad­ded                          int64
# Shares                                    int64
# Dis­likes                                 int64
# Likes                                     int64
# Sub­scribers lost                         int64
# Sub­scribers gained                       int64
# RPM (USD)                               float64
# CPM (USD)                               float64
# Av­er­age per­cent­age viewed (%)       float64
# Av­er­age view dur­a­tion                object
# Views                                     int64
# Watch time (hours)                      float64
# Sub­scribers                              int64
# Your es­tim­ated rev­en­ue (USD)        float64
# Im­pres­sions                             int64
# Im­pres­sions click-through rate (%)    float64
# dtype: object

# %%
df2.dtypes
# Out:
# Date                           object
# Video Title                    object
# External Video ID              object
# Video Length                    int64
# Thumbnail link                 object
# Views                           int64
# Video Likes Added               int64
# Video Dislikes Added            int64
# Video Likes Removed             int64
# User Subscriptions Added        int64
# User Subscriptions Removed      int64
# Average View Percentage       float64
# Average Watch Time            float64
# User Comments Added             int64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# Video                                   0
# Video title                             0
# Video pub­lish time                     0
# Com­ments ad­ded                        0
# Shares                                  0
# Dis­likes                               0
# Likes                                   0
# Sub­scribers lost                       0
# Sub­scribers gained                     0
# RPM (USD)                               0
# CPM (USD)                               2
# Av­er­age per­cent­age viewed (%)       0
# Av­er­age view dur­a­tion               0
# Views                                   0
# Watch time (hours)                      0
# Sub­scribers                            0
# Your es­tim­ated rev­en­ue (USD)        0
# Im­pres­sions                           0
# Im­pres­sions click-through rate (%)    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Date                             0
# Video Title                      0
# External Video ID                0
# Video Length                     0
# Thumbnail link                   0
# Views                            0
# Video Likes Added                0
# Video Dislikes Added             0
# Video Likes Removed              0
# User Subscriptions Added         0
# User Subscriptions Removed       0
# Average View Percentage       1347
# Average Watch Time            1347
# User Comments Added              0
# dtype: int64

# %%
df1[df1['CPM (USD)'].isnull() == True]
# Out:
#            Video                                        Video title  \
# 69   UcilY6HDuL8  10000 Subscriber and 100th Video Special (Data...
# 222  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video pub­lish time  Com­ments ad­ded  Shares  Dis­likes  Likes  \
# 69         May 13, 2020                58      12          4    149
# 222         Jun 6, 2017                 0       2          0      1
#
#      Sub­scribers lost  Sub­scribers gained  RPM (USD)  CPM (USD)  \
# 69                   2                   53       0.00        NaN
# 222                  0                    0       0.05        NaN
#
#      Av­er­age per­cent­age viewed (%) Av­er­age view dur­a­tion  Views  \
# 69                               24.01                   0:00:41   3064
# 222                               8.79                   0:01:04     60
#
#      Watch time (hours)  Sub­scribers  Your es­tim­ated rev­en­ue (USD)  \
# ...

# %%
no_watch = df2[df2['Average Watch Time'].isnull() == True]
no_watch
# Out:
#                 Date                                        Video Title  \
# 214      18 Jan 2022  Reviewing Your Data Science Projects - Episode...
# 252      18 Jan 2022     Can You Learn Data Science Without a Computer?
# 258      18 Jan 2022  His Startup Will Land You a Data Science Job (...
# 292      18 Jan 2022  Is it Important to Share Your Data Science Wor...
# 295      18 Jan 2022  Building a Deep Learning BEAST (NVIDIA TITAN R...
# ...              ...                                                ...
# 111415   12 Nov 2018                     ProjectDemoCSC478_UFCFightData
# 111439   29 Oct 2018  Predicting Season Long NBA Wins Using Multiple...
# 111487  22 Sept 2018  Predicting Season Long NBA Wins Using Multiple...
# 111492  20 Sept 2018  Predicting Season Long NBA Wins Using Multiple...
# 111649   19 May 2018                     ProjectDemoCSC478_UFCFightData
#
#        External Video ID  Video Length  \
# 214          jam0xApfC-U           804
# ...

# %%
df1.drop_duplicates(inplace=True)

# %%
df2.drop_duplicates(inplace=True)

# %%
df1.describe()
# Out:
#        Com­ments ad­ded       Shares   Dis­likes         Likes  \
# count        223.000000   223.000000  223.000000    223.000000
# mean          63.654709   177.753363   17.497758   1008.865471
# std           91.559620   733.331174   69.578517   3577.895609
# min            0.000000     0.000000    0.000000      1.000000
# 25%           18.000000    19.000000    1.000000    163.000000
# 50%           37.000000    46.000000    4.000000    342.000000
# 75%           66.000000   112.500000   11.000000    713.000000
# max          907.000000  9583.000000  942.000000  46903.000000
#
#        Sub­scribers lost  Sub­scribers gained   RPM (USD)   CPM (USD)  \
# count         223.000000           223.000000  223.000000  221.000000
# mean           13.260090           587.309417    4.438300   11.440303
# std            33.242009          3302.316610    1.792295    3.342147
# min             0.000000             0.000000    0.000000    5.439000
# ...

# %%
df2.describe()
# Out:
#         Video Length          Views  Video Likes Added  Video Dislikes Added  \
# count  111856.000000  111856.000000      111856.000000         111856.000000
# mean      874.604107      49.714615           2.095551              0.052425
# std       861.292523     316.558911          14.263757              1.852021
# min        47.000000       0.000000           0.000000              0.000000
# 25%       375.000000       3.000000           0.000000              0.000000
# 50%       548.000000       9.000000           0.000000              0.000000
# 75%       917.000000      28.000000           1.000000              0.000000
# max      5029.000000   35677.000000        1610.000000            289.000000
#
#        Video Likes Removed  User Subscriptions Added  \
# count         111856.00000             111856.000000
# mean               0.08679                  1.169191
# std                1.79354                 12.109119
# min                0.00000                  0.000000
# ...
